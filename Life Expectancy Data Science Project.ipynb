# %% [markdown]
# # Life Expectancy Data Science Project

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('/Users/nikhilkuniyil/Desktop/Data_Science_Regression_Project/Life_Expectancy_Data.csv')

# %%
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1649 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          1649 non-null   object
#  1   Year                             1649 non-null   int64
#  2   Status                           1649 non-null   object
#  3   Life expectancy                  1649 non-null   float64
#  4   Adult Mortality                  1649 non-null   float64
#  5   infant deaths                    1649 non-null   int64
#  6   Alcohol                          1649 non-null   float64
#  7   percentage expenditure           1649 non-null   float64
#  8   Hepatitis B                      1649 non-null   float64
#  9   Measles                          1649 non-null   int64
#  10   BMI                             1649 non-null   float64
#  11  under-five deaths                1649 non-null   int64
# ...

# %%
df.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2928.000000      2928.000000    2938.000000
# mean   2007.518720         69.224932       164.796448      30.303948
# std       4.613841          9.523867       124.292079     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.100000        74.000000       0.000000
# 50%    2008.000000         72.100000       144.000000       3.000000
# 75%    2012.000000         75.700000       228.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# ...

# %% [markdown]
# Mean life expectancy among the entire world is, on average, 69.22 years.

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df.dropna(axis=0, inplace=True)

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
sns.set_style('whitegrid')

# %%
corr = df.corr()
plt.figure(figsize=(12,8))
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns,
        annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.jointplot(x='Adult Mortality', y='Life expectancy ', data=df)

# %%
sns.jointplot(x='infant deaths', y='Life expectancy ', data=df)

# %% [markdown]
# ## Should a country having a lower life expectancy value(<65) increase its healthcare expenditure in order to improve its average lifespan?

# %%
low_expectancy = df[df['Life expectancy '] < 65]
low_expectancy.head(10)
# Out:
#         Country  Year      Status  Life expectancy   Adult Mortality  \
# 1   Afghanistan  2014  Developing              59.9            271.0
# 2   Afghanistan  2013  Developing              59.9            268.0
# 3   Afghanistan  2012  Developing              59.5            272.0
# 4   Afghanistan  2011  Developing              59.2            275.0
# 5   Afghanistan  2010  Developing              58.8            279.0
# 6   Afghanistan  2009  Developing              58.6            281.0
# 7   Afghanistan  2008  Developing              58.1            287.0
# 8   Afghanistan  2007  Developing              57.5            295.0
# 9   Afghanistan  2006  Developing              57.3            295.0
# 10  Afghanistan  2005  Developing              57.3            291.0
#
#     infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 1              64     0.01               73.523582         62.0       492
# ...

# %% [markdown]
# high_expectancy = df[df['Life expectancy '] >= 65]
# high_expectancy.head(10)

# %%
low_expectancy_expenditure = low_expectancy['Total expenditure'].mean()
low_expectancy_expenditure
# Out:
# 5.730751708428247

# %%
high_expectancy_expenditure = high_expectancy['Total expenditure'].mean()
high_expectancy_expenditure
# Out:
# 6.037619834710738

# %% [markdown]
# On averge, countries with a lower life expectancy value (life expectancy below 65), on average, spend a total of 5.73% of their entire government's money supply on health. However, countries with a higher life expectancy ( > 65 years) spend an average of 6.04% of their government's budget.

# %% [markdown]
# Majority of the countries that can be classified as having a higher life expectancy are located in Europe, North-America, and parts of Asia. These governments have trillions of dollars more than their lower-life-expectancy value counterparts. The fact that not only do higher life expectancy countries have a significantly greater amount of money at their disposal, they are spending a greater percentage of their budget on health, which correlates positively with their higher life expectancy values.

# %%
Over, based on the data, countries should consider increase its healthcare expenditure in order to improve its average lifespan.

# %% [markdown]
# ## Does Life Expectancy has positive or negative correlation with eating habits, lifestyle, exercise, smoking, drinking alcohol etc.

# %%
plt.figure(figsize=(10, 4))
hm = sns.heatmap(df[[' thinness  1-19 years', ' thinness 5-9 years', 'Alcohol', 'Life expectancy ']].corr(), annot=True)
hm.set(xlabel='\nLife Expectancy Details', ylabel='Life Expectancy Details\t', 
       title = "Correlation matrix of Life Expectancy data\n")
hm
# Out:
# <AxesSubplot:title={'center':'Correlation matrix of Life Expectancy data\n'}, xlabel='\nLife Expectancy Details', ylabel='Life Expectancy Details\t'>
# /Users/nikhilkuniyil/Documents/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df[[' thinness  1-19 years', ' thinness 5-9 years', 'Alcohol']].corrwith(df['Life expectancy '])
# Out:
#  thinness  1-19 years   -0.457838
#  thinness 5-9 years     -0.457508
# Alcohol                  0.402718
# dtype: float64

# %%
sns.scatterplot(x=' thinness  1-19 years', y='Life expectancy ', data=df)
# Out:
# <AxesSubplot:xlabel=' thinness  1-19 years', ylabel='Life expectancy '>

# %%
sns.scatterplot(x='Alcohol', y='Life expectancy ', data=df)
# Out:
# <AxesSubplot:xlabel='Alcohol', ylabel='Life expectancy '>

# %% [markdown]
# As shown in the heatmap and the scatterplots, life expectancy has a negative correlation with the 'thinness 1-19 years' and the 'thinness 5-9 years' column. This can be attributed to the lack of adequate food in developing countries, which can lead to an increased chance of early death, or a lower life expectancy.

# %% [markdown]
# In addition, alcohol can be seen to have a positive correlation with life expectancy, which contradicts all current
# knowledge about the effects of alcohol. However, I believe this can be attributed to the fact that people living in
# more developed countries, or countries with a higher life expectancy, are more likely to have access to alcohol, hence why consumption in those respective countries are high, and positively correlated with life expectancy.

# %% [markdown]
# ## What is the impact of schooling on the lifespan of humans?

# %%
df[['Life expectancy ', 'Schooling']].groupby(df['Status']).mean()
# Out:
#             Life expectancy   Schooling
# Status
# Developed          79.197852  15.845474
# Developing         67.111465  11.219256

# %%
sns.lmplot(x='Schooling', y='Life expectancy ', data=df)

# %% [markdown]
# As shown, in developed countries, where the life expectancy is 15.26% higher than that of developing countries,
# the average number of years spent in schooling is on average 29.2% higher. Moreover, the plot above displays a
# strong positive correlation between the average number of years spent in schooling and the life expectancy.

# %% [markdown]
# A country looking to increase its aveage life expectancy should, therefore, place more effort on placing an
# emphasis on education and schooling.

# %% [markdown]
# ## Do densely populated countries tend to have lower life expectancy?

# %%
sns.scatterplot(x='Population', y='Life expectancy ', data=df)
# Out:
# <AxesSubplot:xlabel='Population', ylabel='Life expectancy '>

# %%
df['Population'].describe()
# Out:
# count    2.286000e+03
# mean     1.275338e+07
# std      6.101210e+07
# min      3.400000e+01
# 25%      1.957932e+05
# 50%      1.386542e+06
# 75%      7.420359e+06
# max      1.293859e+09
# Name: Population, dtype: float64

# %% [markdown]
# Since the median population is 1386542, we will use this value to divide the dataframe into countries that are highly
# populated (population > 1386542), and countries that are lowly populated (population < 1386542).

# %%
def popLevel(x):
    if x <= 1386542:
        x = 'Low'
    else:
        x = 'High'
    return x

# %%
df['Population Level'] = df['Population'].apply(lambda x: popLevel(x))
df.head(10)
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
# 5  Afghanistan  2010  Developing              58.8            279.0
# 6  Afghanistan  2009  Developing              58.6            281.0
# 7  Afghanistan  2008  Developing              58.1            287.0
# 8  Afghanistan  2007  Developing              57.5            295.0
# 9  Afghanistan  2006  Developing              57.3            295.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# ...

# %%
high_pop = df[df['Population Level'] == 'High']
print(f"Countries classified as having a high population have an average population of {high_pop['Population'].mean():.2f}.")
low_pop = df[df['Population Level'] == 'Low']
print(f"Countries classified as having a low population have an average population of {low_pop['Population'].mean():.2f}.")
# Out:
# Countries classified as having a high population have an average population of 25136168.10.
# Countries classified as having a low population have an average population of 370582.14.

# %%
df['Life expectancy '].groupby(df['Population Level']).mean()
# Out:
# Population Level
# High    69.097706
# Low     69.424189
# Name: Life expectancy , dtype: float64

# %%
df['Life expectancy '].corr(df['Population'])
# Out:
# -0.021538108386786478

# %%
plt.figure(figsize=(10,5))
plt.title('Life Expectancy vs. Population Level')
sns.barplot(x='Population Level', y='Life expectancy ', data=df)
# Out:
# <AxesSubplot:title={'center':'Life Expectancy vs. Population Level'}, xlabel='Population Level', ylabel='Life expectancy '>

# %% [markdown]
# As indicated by the data, there is no relationship between the population of a country and its respective average life
# expectancy. Both highly populated and lowly populated countries have an average life expectancy of approximately 69
# years, as indicated by barplot.

# %% [markdown]
# To answer the important question, densely populated countries do not tend to have a lower life expectancy.

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# Now that we've explored the data, let's go ahead and split the data into training and testing sets, in order to
# establish a linear model between all other numerical columns and 'life expectancy'.

# %%
non_floats = []
for col in df:
    if df[col].dtypes != "float64" and df[col].dtypes != "int64":
        non_floats.append(col)
df = df.drop(columns=non_floats)
df = df.dropna()
df
# Out:
#       Year  Life expectancy   Adult Mortality  infant deaths  Alcohol  \
# 0     2015              65.0            263.0             62     0.01
# 1     2014              59.9            271.0             64     0.01
# 2     2013              59.9            268.0             66     0.01
# 3     2012              59.5            272.0             69     0.01
# 4     2011              59.2            275.0             71     0.01
# ...    ...               ...              ...            ...      ...
# 2933  2004              44.3            723.0             27     4.36
# 2934  2003              44.5            715.0             26     4.06
# 2935  2002              44.8             73.0             25     4.43
# 2936  2001              45.3            686.0             25     1.72
# 2937  2000              46.0            665.0             24     1.68
#
#       percentage expenditure  Hepatitis B  Measles    BMI   \
# 0                  71.279624         65.0      1154   19.1
# ...

# %%
X = df.drop(columns=['Year', 'Life expectancy '])
y = df['Life expectancy ']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
predictions = lm.predict(X_test)

# %%
plt.scatter(y_test,predictions)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
plt.title('Y Test vs. Predicted Y')
# Out:
# Text(0.5, 1.0, 'Y Test vs. Predicted Y')

# %%
from sklearn import metrics

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, predictions))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, predictions))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# Mean Absolute Error: 2.7904475551069057
# Mean Squared Error: 13.291439818330076
# Root Mean Squared Error: 3.6457426977681893

# %%
from sklearn.metrics import r2_score

# %%
print('The r-squared value for our test data was',r2_score(y_test,predictions))
# Out:
# The r-squared value for our test data was 0.8142062300838303

# %%
The R2 score can be used as a performance marker of a linear regression model. The r-squared value shows that the
data the model  was fed accounted  for 81.42% of the variance.

# %% [markdown]
# ## Conclusion

# %%
To conclude, lets examine which feature of our original dataframe has the largest effect on life expectancy. We
can do this by interpreting the coefficients.

# %%
coeffecients = pd.DataFrame(lm.coef_,X.columns)
coeffecients.columns = ['Coeffecient']
coeffecients
# Out:
#                                   Coeffecient
# Adult Mortality                 -1.716466e-02
# infant deaths                    9.161421e-02
# Alcohol                         -2.254523e-02
# percentage expenditure           3.329311e-04
# Hepatitis B                     -3.464140e-03
# Measles                         -7.907624e-06
#  BMI                             2.752181e-02
# under-five deaths               -6.887080e-02
# Polio                            6.671814e-03
# Total expenditure                7.307442e-02
# Diphtheria                       1.010713e-02
#  HIV/AIDS                       -4.203749e-01
# GDP                              1.210020e-05
# Population                      -4.336582e-11
#  thinness  1-19 years            2.296367e-03
#  thinness 5-9 years             -7.333952e-02
# Income composition of resources  9.383504e+00
# Schooling                        9.362274e-01

# %% [markdown]
# The category that would have one of the largest effects on the life expectancy of a country is
# 'Schooling'. Holding all other features fixed, a 1 unit increase in the number of years spent in schooling is
# associated with an increase in the average life expectrancy by 0.9 years.
